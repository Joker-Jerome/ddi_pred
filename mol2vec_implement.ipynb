# %%
from mol2vec import features
from mol2vec import helpers
import os
import pickle
import numpy as np
import pandas as pd
import sys

from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import IPythonConsole

from mol2vec.features import mol2alt_sentence, mol2sentence, MolSentence, DfVec, sentences2vec
from gensim.models import word2vec
# Out:
# RDKit WARNING: [21:39:16] Enabling RDKit 2019.09.3 jupyter extensions

# %%
model = word2vec.Word2Vec.load('model_300dim.pkl')

df = PandasTools.LoadSDF('structures.sdf', idName='ID', molColName='ROMol', includeFingerprints=False, isomericSmiles=True, smilesName=None, embedProps=False, removeHs=True, strictParsing=True)
# Out:
# RDKit ERROR: [21:44:28] Explicit valence for atom # 7 N, 4, is greater than permitted
# RDKit ERROR: [21:44:28] ERROR: Could not sanitize molecule ending on line 21598
# RDKit WARNING: [21:44:28] Warning: conflicting stereochemistry at atom 5 ignored.
# RDKit WARNING: [21:44:28] Warning: conflicting stereochemistry at atom 5 ignored.
# RDKit ERROR: [21:44:28] ERROR: Explicit valence for atom # 7 N, 4, is greater than permitted
# RDKit ERROR: [21:44:29] Explicit valence for atom # 13 Cl, 5, is greater than permitted
# RDKit ERROR: [21:44:29] ERROR: Could not sanitize molecule ending on line 287346
# RDKit ERROR: [21:44:29] ERROR: Explicit valence for atom # 13 Cl, 5, is greater than permitted
# RDKit ERROR: [21:44:29] Explicit valence for atom # 39 N, 5, is greater than permitted
# RDKit ERROR: [21:44:29] ERROR: Could not sanitize molecule ending on line 326226
# RDKit WARNING: [21:44:29] Warning: conflicting stereochemistry at atom 37 ignored.
# RDKit WARNING: [21:44:29] Warning: conflicting stereochemistry at atom 37 ignored.
# RDKit WARNING: [21:44:29] Warning: conflicting stereochemistry at atom 37 ignored.
# RDKit ERROR: [21:44:29] ERROR: Explicit valence for atom # 39 N, 5, is greater than permitted
# RDKit ERROR: [21:44:29] Explicit valence for atom # 70 O, 3, is greater than permitted
# RDKit ERROR: [21:44:29] ERROR: Could not sanitize molecule ending on line 397138
# RDKit ERROR: [21:44:29] ERROR: Explicit valence for atom # 70 O, 3, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 2 O, 3, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 510889
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 2 O, 3, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 519958
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 574862
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 584721
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 610117
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 6 Be, 4, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 618913
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 6 Be, 4, is greater than permitted
# RDKit ERROR: [21:44:30] Explicit valence for atom # 20 N, 4, is greater than permitted
# RDKit ERROR: [21:44:30] ERROR: Could not sanitize molecule ending on line 630456
# RDKit ERROR: [21:44:30] ERROR: Explicit valence for atom # 20 N, 4, is greater than permitted
# RDKit ERROR: [21:44:32] Explicit valence for atom # 0 Be, 3, is greater than permitted
# RDKit ERROR: [21:44:32] ERROR: Could not sanitize molecule ending on line 1081397
# RDKit WARNING: [21:44:32] Warning: conflicting stereochemistry at atom 71 ignored.
# RDKit WARNING: [21:44:32] Warning: conflicting stereochemistry at atom 71 ignored.
# RDKit ERROR: [21:44:32] ERROR: Explicit valence for atom # 0 Be, 3, is greater than permitted
# RDKit ERROR: [21:44:32] Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [21:44:32] ERROR: Could not sanitize molecule ending on line 1236868
# RDKit ERROR: [21:44:32] ERROR: Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [21:44:33] Explicit valence for atom # 1 Cl, 4, is greater than permitted
# RDKit ERROR: [21:44:33] ERROR: Could not sanitize molecule ending on line 1417843
# RDKit ERROR: [21:44:33] ERROR: Explicit valence for atom # 1 Cl, 4, is greater than permitted
# RDKit ERROR: [21:44:33] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [21:44:33] ERROR: Could not sanitize molecule ending on line 1652876
# RDKit ERROR: [21:44:33] ERROR: Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [21:44:33] Explicit valence for atom # 6 K, 2, is greater than permitted
# RDKit ERROR: [21:44:33] ERROR: Could not sanitize molecule ending on line 1659564
# RDKit ERROR: [21:44:33] ERROR: Explicit valence for atom # 6 K, 2, is greater than permitted
# RDKit ERROR: [21:44:33] Explicit valence for atom # 12 Mg, 4, is greater than permitted
# RDKit ERROR: [21:44:33] ERROR: Could not sanitize molecule ending on line 1661650
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 21 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 21 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 26 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 41 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 41 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 83 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 83 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 107 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 107 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 26 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 26 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 26 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 41 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 41 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 137 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 137 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 9 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 9 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 18 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 18 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 28 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 28 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 55 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 55 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 86 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 86 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 10 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 58 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 58 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 93 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 93 ignored.
# RDKit WARNING: [21:44:34] Warning: conflicting stereochemistry at atom 10 ignored.

# %%
df['sentence'] = df.apply(lambda x: MolSentence(mol2alt_sentence(x['ROMol'], 1)), axis=1)
df['mol2vec'] = [DfVec(x) for x in sentences2vec(df['sentence'], model, unseen='UNK')]

# %%
X_pre = np.array([x.vec for x in df['mol2vec']])

# %%
#set directory
os.getcwd()
os.chdir("/Users/varun/MEGA/Python/Data")

#list of desired DDI Types
desired_DDI = [0, 1, 2, 3, 4, 5, 6, 7, 15, 16, 17, 18, 19, 20, 21, 22, 26, 28, 30, 31, 32, 38, 40, 41, 43, 44, 45,
               49, 50, 51, 52, 54, 55, 62, 67, 68, 72, 74, 76, 78, 79, 80, 81]

ddidata = pd.read_excel("DrugBank_known_ddi.xlsx")
interactiondict = pd.read_csv("interaction_information.csv")
safe_drugs = pd.read_csv("safe_drug_combos.csv")
drug_similarity_feature = pd.read_csv("drug_similarity.csv")
drug_similarity = drug_similarity_feature.iloc[:, 1:len(drug_similarity_feature)+1]
#filter ddidata for desired DDI types
up_ddidata = ddidata[ddidata.Label.isin(desired_DDI)]
new_ddidata = up_ddidata.copy()
#convert types to int
new_ddidata.drug1 = up_ddidata.drug1.str[2:].astype(int)
new_ddidata.drug2 = up_ddidata.drug2.str[2:].astype(int)
new_ddidata.Label = up_ddidata.Label

# %%
#Incorporate safe_drugs into new_ddidata with DDIType 0
safe_drugs["Label"] = 0

frames = [safe_drugs, new_ddidata]
ddi_df = pd.concat(frames)

#create a DB to index dictionary from similarity dataset
DB_to_index = {}
i = 0
for col in drug_similarity.columns:
    DB_to_index[int(col[2:7])] = i
    i = i + 1

#filter output to only include DBs with similarity features
ddi_df_output = ddi_df[ddi_df.drug1.isin(DB_to_index)]
ddi_output = ddi_df_output[ddi_df_output.drug2.isin(DB_to_index)]
ddi_df_output.tail()
# Out:
#         drug1  drug2  Label
# 190256    655    461     81
# 190257   1041    367     81
# 190258   1395    302     81
# 190259    302   1357     81
# 190260    480    655     81

# %%
count = {}
#initialize dict
for i in range(0, 82):
    count[i] = 0
    
#count number of examples for each DDItype
for i in range(0, 82):
    if i in desired_DDI:
        count[i] = len(ddi_output[ddi_output.Label == (i)])

# %%
#create a structures matrix (SMILES)  for each drug-drug pair
i = 0
X = np.zeros((len(ddi_output), 600))
for index, row in ddi_output.iterrows():
        drug1_index = DB_to_index[row["drug1"]]
        drug2_index = DB_to_index[row["drug2"]]
        X[drug1_index,0:299] = X_pre[drug1_index, 0:299]
        X[drug2_index, 300:599] = X_pre[drug2_index, 0:299]

# %%
import tensorflow as tf
import sklearn.model_selection
#Create input and output vectors for training

y_data = np.array(ddi_output.Label)

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y_data, test_size = 0.4
                                                                           , random_state =1)
X_test, X_val, y_test, y_val = sklearn.model_selection.train_test_split(X_test, y_test, test_size = 0.5
                                                                       , random_state = 1)

train_set = tf.data.Dataset.from_tensor_slices((X_train, y_train))
validation_set = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_set = tf.data.Dataset.from_tensor_slices((X_test, y_test))

BATCH_SIZE = 256
SHUFFLE_BUFFER_SIZE = 1024

train_set = train_set.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_set = test_set.batch(BATCH_SIZE)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5000, activation = 'relu', input_dim = 600),
    tf.keras.layers.Dense(5000, activation = 'relu'),
    tf.keras.layers.Dense(5000, activation = 'relu', input_dim = 600),
    tf.keras.layers.Dense(5000, activation = 'relu', input_dim = 600),
    tf.keras.layers.Dense(82, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-5),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
model.fit(train_set, epochs=50)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 15s 61ms/step - loss: 4.3392 - sparse_categorical_accuracy: 0.5500
# Epoch 2/100
# 240/240 [==============================] - 15s 63ms/step - loss: 4.2829 - sparse_categorical_accuracy: 0.6147
# Epoch 3/100
# 240/240 [==============================] - 16s 67ms/step - loss: 4.2166 - sparse_categorical_accuracy: 0.6147
# Epoch 4/100
# 240/240 [==============================] - 17s 69ms/step - loss: 4.1260 - sparse_categorical_accuracy: 0.6147
# Epoch 5/100
# 240/240 [==============================] - 17s 69ms/step - loss: 4.0125 - sparse_categorical_accuracy: 0.6147
# Epoch 6/100
# 240/240 [==============================] - 16s 69ms/step - loss: 3.8785 - sparse_categorical_accuracy: 0.6147
# Epoch 7/100
# 240/240 [==============================] - 16s 65ms/step - loss: 3.7262 - sparse_categorical_accuracy: 0.6147
# Epoch 8/100
# 195/240 [=======================>......] - ETA: 2s - loss: 3.5727 - sparse_categorical_accuracy: 0.6147
