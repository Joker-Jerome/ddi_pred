# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import datetime
import argparse
import sys
import sklearn.model_selection

#set directory
os.getcwd()
os.chdir("/Users/varun/MEGA/Python/Data")

#list of desired DDI Types
desired_DDI = [0, 1, 2, 3, 4, 5, 6, 7, 15, 16, 17, 18, 19, 20, 21, 22, 26, 28, 30, 31, 32, 38, 40, 41, 43, 44, 45,
               49, 50, 51, 52, 54, 55, 62, 67, 68, 72, 74, 76, 78, 79, 80, 81]

ddidata = pd.read_excel("DrugBank_known_ddi.xlsx")
interactiondict = pd.read_csv("interaction_information.csv")
safe_drugs = pd.read_csv("safe_drug_combos.csv")
drug_similarity_feature = pd.read_csv("drug_similarity.csv")
drug_similarity = drug_similarity_feature.iloc[:, 1:len(drug_similarity_feature)+1]
#filter ddidata for desired DDI types
up_ddidata = ddidata[ddidata.Label.isin(desired_DDI)]
new_ddidata = up_ddidata.copy()
#convert types to int
new_ddidata.drug1 = up_ddidata.drug1.str[2:].astype(int)
new_ddidata.drug2 = up_ddidata.drug2.str[2:].astype(int)
new_ddidata.Label = up_ddidata.Label

# %%
#Incorporate safe_drugs into new_ddidata with DDIType 0
safe_drugs["Label"] = 0

frames = [safe_drugs, new_ddidata]
ddi_df = pd.concat(frames)

#create a DB to index dictionary from similarity dataset
DB_to_index = {}
i = 0
for col in drug_similarity.columns:
    DB_to_index[int(col[2:7])] = i
    i = i + 1

#filter output to only include DBs with similarity features
ddi_df_output = ddi_df[ddi_df.drug1.isin(DB_to_index)]
ddi_output = ddi_df_output[ddi_df_output.drug2.isin(DB_to_index)]
ddi_df_output.tail()
# Out:
#         drug1  drug2  Label
# 190256    655    461     81
# 190257   1041    367     81
# 190258   1395    302     81
# 190259    302   1357     81
# 190260    480    655     81

# %%
count = {}
#initialize dict
for i in range(0, 82):
    count[i] = 0
    
#count number of examples for each DDItype
for i in range(0, 82):
    if i in desired_DDI:
        count[i] = len(ddi_output[ddi_output.Label == (i)])

# %%
#add similarity feature for each drug-drug pair
sim_array = []
i = 0
for index, row in ddi_output.iterrows():
        drug1_index = DB_to_index[row["drug1"]]
        drug2_index = DB_to_index[row["drug2"]]
        sim_array.append(drug_similarity.iloc[drug1_index, drug2_index])

# %%
#plot count
plt.bar(range(len(count)), list(count.values()))
plt.xlabel("DDI Type")
plt.ylabel("Count")
plt.show()

# %%
import tensorflow as tf
#Create input and output vectors for training

X_data = np.array(sim_array)
y_data = np.array(ddi_output.Label)

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X_data, y_data, test_size = 0.4
                                                                           , random_state =1)
X_test, X_val, y_test, y_val = sklearn.model_selection.train_test_split(X_test, y_test, test_size = 0.5
                                                                       , random_state = 1)

train_set = tf.data.Dataset.from_tensor_slices((X_train, y_train))
validation_set = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_set = tf.data.Dataset.from_tensor_slices((X_test, y_test))

BATCH_SIZE = 256
SHUFFLE_BUFFER_SIZE = 1024

train_set = train_set.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_set = test_set.batch(BATCH_SIZE)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5000, activation = 'relu', input_dim = 1),
    tf.keras.layers.Dense(82, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-5),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
model.fit(train_set, epochs=10)
# Out:
# Epoch 1/10
# 240/240 [==============================] - 3s 14ms/step - loss: 4.4049 - sparse_categorical_accuracy: 0.0698
# Epoch 2/10
# 240/240 [==============================] - 3s 11ms/step - loss: 4.3814 - sparse_categorical_accuracy: 0.1287
# Epoch 3/10
# 240/240 [==============================] - 3s 12ms/step - loss: 4.3574 - sparse_categorical_accuracy: 0.3474
# Epoch 4/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.3322 - sparse_categorical_accuracy: 0.5782
# Epoch 5/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.3053 - sparse_categorical_accuracy: 0.5986
# Epoch 6/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.2764 - sparse_categorical_accuracy: 0.5988
# Epoch 7/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.2454 - sparse_categorical_accuracy: 0.5988
# Epoch 8/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.2122 - sparse_categorical_accuracy: 0.5988
# Epoch 9/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.1767 - sparse_categorical_accuracy: 0.5988
# Epoch 10/10
# 240/240 [==============================] - 3s 13ms/step - loss: 4.1389 - sparse_categorical_accuracy: 0.5988

# %%
model.evaluate(X_val,  y_val, verbose=2)
# Out:
# 20399/1 - 1s - loss: 4.1334 - sparse_categorical_accuracy: 0.5951
# [4.119000257104687, 0.5951272]
